# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("스카이캐슬긍정부정.csv")
df.head()
# Out:
#                                              comment             hour  pos  \
# 0                                          부부 2부 개지루  2020-07-25 22:2    0
# 1                                      종이비행기는 아니지 않냐  2020-07-25 22:2    0
# 2                           여기에디오오빠가왜나오죠?디오오빠는출연안했는데  2020-07-17 15:3    0
# 3  저도 같은 생각이었어요 디오 연기 볼 때마다 아이돌 맞아? 라고 놀랄 때가 많았는데...  2020-06-25 11:2    0
# 4  설강화 김혜윤 출연 확정되면 상대배우 도경수가 하면 완전 대박날것 같은데. 둘다 연...  2020-06-25 11:0    1
#
#    neg
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1

# %%
# 시간대별로 긍정 부정 단어 수를 묶어주세요! groupby sum!

# %%
temp = df['pos'].sort_values(ascending=False)
plt.plot(temp.values)

# %%
temp = df['neg'].sort_values(ascending=False)
plt.plot(temp.values)
