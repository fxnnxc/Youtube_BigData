# %% [markdown]
# <a href="https://colab.research.google.com/github/fxnnxc/Youtube_BigData/blob/master/script_crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api
from youtube_transcript_api import YouTubeTranscriptApi

# %%
# 알라딘
YouTubeTranscriptApi.get_transcript("6NqKrhmnVNY")
# Out:
# [{'duration': 1.86, 'start': 0.3, 'text': '♫ "ARABIAN NIGHT" instrumental ♫'},
#  {'duration': 1.38, 'start': 18.56, 'text': 'Bring me the lamp.'},
#  {'duration': 1.7, 'start': 21.7, 'text': 'Your life begins now...'},
#  {'duration': 1.08, 'start': 28.12, 'text': 'Aladdin.'},
#  {'duration': 2.74,
#   'start': 29.7,
#   'text': '♫ "FRIEND LIKE ME" instrumental ♫'},
#  {'duration': 0.76, 'start': 49.8, 'text': 'Woo!'},
#  {'duration': 1.26, 'start': 51.28, 'text': "You really don't know who I am?"},
#  {'duration': 0.58, 'start': 52.72, 'text': 'Genie,'},
#  {'duration': 1.42, 'start': 53.4, 'text': 'wishes, lamp,'},
#  {'duration': 1.04, 'start': 55.1, 'text': 'none of that ringing a bell?'}]

# %%
# 런닝맨
YouTubeTranscriptApi.get_transcript("J8dKX0Dem5w", languages=['ko'])
# Out:
# [{'duration': 5.91,
#   'start': 0.0,
#   'text': '제가 줘 때 여자가 걸그룹들 많이 쓰며 돼도 오빠 저희가 같은 비행기'},
#  {'duration': 7.88, 'start': 4.74, 'text': '사신 거에요'},
#  {'duration': 6.71, 'start': 5.91, 'text': '중국 스케쥴이 어느 수행 나왔는데 내리자마자 그양 팬분들이'},
#  {'duration': 7.2,
#   'start': 14.39,
#   'text': 'o 지금 예전의 그럴 줄 알고 교 억울한 26a 아아아 아 열릴 때 다'},
#  {'duration': 4.44, 'start': 21.05, 'text': '있잖아요'},
#  {'duration': 10.11, 'start': 21.59, 'text': '으 감상하세요 뭔지 뵙고'},
#  {'duration': 9.44,
#   'start': 25.49,
#   'text': '예 4 들어가시면 그랬어 예 아 더 목적에서 지속 진도 그룹 난리가 났'},
#  {'duration': 3.23, 'start': 31.7, 'text': '어 없어요 그렇죠'},
#  {'duration': 7.14,
#   'start': 36.2,
#   'text': '으 그 줄 어떻게 할 거니 앞으로 그 사약 어 그 중을 쭉 할 거야'},
#  {'duration': 7.32, 'start': 40.64, 'text': '어떡할까 얘는 배워서 올 거야 아니면 은 봐야지'},
#  {'duration': 7.74,
#   'start': 43.34,
#   'text': '아가 하자 해서 어이가 위주의 어디 롤 모델이 있어 쟤는 쪽에 롤모델이'},
#  {'duration': 9.63, 'start': 47.96, 'text': '제현이 선배님이 아아 이 거리 2'},
#  {'duration': 11.159,
#   'start': 51.08,
# ...

# %%
# 팝송
YouTubeTranscriptApi.get_transcript("s9DDX17ADI4", languages=['en'])
# Out:
# [{'duration': 4.8, 'start': 7.2, 'text': "i ain't worried about nothing"},
#  {'duration': 3.84,
#   'start': 9.44,
#   'text': "i ain't worried about nada you're"},
#  {'duration': 4.88, 'start': 12.0, 'text': 'sitting pretty'},
#  {'duration': 3.919,
#   'start': 13.28,
#   'text': 'impatient girl i know you gotta put them'},
#  {'duration': 3.92, 'start': 16.88, 'text': 'in'},
#  {'duration': 6.24, 'start': 17.199, 'text': 'hours baby make it harder'},
#  {'duration': 4.559,
#   'start': 20.8,
#   'text': "you're sitting pick up the picture girl"},
#  {'duration': 7.031, 'start': 23.439, 'text': 'give me five'},
#  {'duration': 8.231, 'start': 25.359, 'text': "you know i'm always on"},
#  {'duration': 3.12, 'start': 30.47, 'text': '[Music]'},
#  {'duration': 6.819, 'start': 37.87, 'text': '[Music]'},
#  {'duration': 21.56,
#   'start': 51.44,
#   'text': "work work work i ain't gotta go to work"},
#  {'duration': 17.49, 'start': 58.8, 'text': 'quack quack'},
# ...

# %%
# 빅
YouTubeTranscriptApi.get_transcript("ICPgfkZgvb0", languages=['ko'])
# Out:
# [{'duration': 0.55, 'start': 0.0, 'text': '아'},
#  {'duration': 0.8, 'start': 0.19, 'text': '[음악]'},
#  {'duration': 1.32, 'start': 0.55, 'text': '[박수]'},
#  {'duration': 5.53, 'start': 0.99, 'text': '[음악]'},
#  {'duration': 8.31, 'start': 1.87, 'text': '으 er'},
#  {'duration': 7.59, 'start': 6.52, 'text': '왜 mp 그대로 부디 신라 그랬어'},
#  {'duration': 9.419, 'start': 10.18, 'text': '기아 신 버블의 아니 아무리 이 몸이 고파도 그렇죠'},
#  {'duration': 13.429,
#   'start': 14.11,
#   'text': '이안은 18살 짜리 청소년 몸이 들어 있어 이러한 느낌이'},
#  {'duration': 13.64,
#   'start': 19.599,
#   'text': '문제시 갖던 다가왔을 때 이런 느낌이 있어 아 정말 입'},
#  {'duration': 10.441, 'start': 27.539, 'text': '이거 뭔가 뭐야 설명 아 거 버겐 가봤어'},
#  {'duration': 9.181, 'start': 33.239, 'text': '큰데 못 봤어 그 중요한 순간에 딴 자고 있었거든'},
#  {'duration': 7.07,
#   'start': 37.98,
#   'text': '학교 행사 준비로 밤을 새서 인제 씨가 커피 사러 간 사용함 빡 좋아'},
#  {'duration': 2.63, 'start': 42.42, 'text': '놓고 있었어요'},
#  {'duration': 3.21, 'start': 51.42, 'text': '아'},
# ...
